# %% [markdown]
# # Elevation - Digital Terrain Model of Plovdiv

# %%
import rasterio as rio
import os
import fiona
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

# %%
import urllib.request

# %% [markdown]
# ## Elevation data

# %% [markdown]
# Shuttle Radar Topography Mission (SRTM)

# %% [markdown]
# U.S. Geological Survey

# %% [markdown]
# EarthExplorer https://earthexplorer.usgs.gov/

# %% [markdown]
# Visit the USGS at https://usgs.gov.

# %% [markdown]
# ## Original data managing

# %%
#demplovdiv = rio.open(r"C:\Users\User\Documents\UNITN\Geospatial\raster\plovdiv\ASTGTMV003_N42E024_dem.tif")

# %%
#In order to retrieve the file:
nameurl = 'https://github.com/atanasova16/GeospatialAnalysisProject/raw/main/Analysis_and_Exploration/Data/DTM/ASTGTMV003_N42E024_dem.tif'
filename = "ASTGTMV003_N42E024_dem.tif"
urllib.request.urlretrieve(nameurl ,filename) 
demplovdiv = rasterio.open(os.path.join(os.getcwd(), filename))
show(demplovdiv)

# %%
demplovdiv.profile
# Out:
# {'driver': 'GTiff', 'dtype': 'int16', 'nodata': None, 'width': 3601, 'height': 3601, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.000277777777777778, 0.0, 23.9998611111111,
#        0.0, -0.000277777777777778, 43.0001388888889), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'band'}

# %%
show(demplovdiv.read(1))

# %% [markdown]
# Profile of altitude

# %%
rio.plot.show_hist(demplovdiv, bins=50, lw=0.0, stacked=False, alpha=0.3,histtype='stepfilled', title="Histogram")

# %% [markdown]
# Contour lines

# %%
dem_array = demplovdiv.read(1).astype('float64')
fig, ax = plt.subplots(1, figsize=(12, 12))
show(dem_array, cmap='Greys_r', ax=ax)
show(dem_array, contour=True, ax=ax, linewidths=0.7)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Read Plovdiv

# %%
municipalities = gpd.read_file("https://raw.githubusercontent.com/atanasova16/GeospatialAnalysisProject/main/Analysis_and_Exploration/Data/Bulgaria_gdf/municipalities.geojson")

# %%
#municipalities = gpd.read_file("C:\\Users\\User\\Documents\\UNITN\\Geospatial\\raster\\municipalities.geojson")
municipalities.crs #4326
municipalities.tail()
# Out:
#      nuts4 nuts3                                           geometry
# 260  PDV22   PDV  POLYGON ((24.76400 42.19200, 24.77800 42.17600...
# 261  DOB28   DOB  POLYGON ((27.88400 43.61300, 27.88400 43.58300...
# 262  SFO57   SFO  POLYGON ((24.10100 42.65800, 24.10000 42.65600...
# 263  SFO58   SFO  POLYGON ((24.07600 42.75100, 24.10500 42.71600...
# 264  JAM26   JAM  POLYGON ((26.53200 42.54800, 26.52300 42.51000...

# %%
plovdiv_city = municipalities[municipalities.nuts4 == "PDV22"]
plovdiv = municipalities[municipalities.nuts3 == "PDV"]

# %%
plovdiv_city.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5778c936a04ba4b5e93aacb21e15394 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5778c936a04ba4b5e93aacb21e15394&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5778c936a04ba4b5e93aacb21e15394 = L.map(
#                 &quot;map_a5778c936a04ba4b5e93aacb21e15394&quot;,
#                 {
#                     center: [42.1445, 24.741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a5778c936a04ba4b5e93aacb21e15394);
#
#
#
#
#
#             var tile_layer_6659d006837debbf30075a68de7068c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a5778c936a04ba4b5e93aacb21e15394);
#
#
#             map_a5778c936a04ba4b5e93aacb21e15394.fitBounds(
#                 [[42.093, 24.658], [42.196, 24.824]],
#                 {}
#             );
#
#
#         function geo_json_4ef2122f73840035afef42ba53656462_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4ef2122f73840035afef42ba53656462_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4ef2122f73840035afef42ba53656462_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4ef2122f73840035afef42ba53656462_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4ef2122f73840035afef42ba53656462_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4ef2122f73840035afef42ba53656462.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4ef2122f73840035afef42ba53656462_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4ef2122f73840035afef42ba53656462 = L.geoJson(null, {
#                 onEachFeature: geo_json_4ef2122f73840035afef42ba53656462_onEachFeature,
#
#                 style: geo_json_4ef2122f73840035afef42ba53656462_styler,
#                 pointToLayer: geo_json_4ef2122f73840035afef42ba53656462_pointToLayer
#         });
#
#         function geo_json_4ef2122f73840035afef42ba53656462_add (data) {
#             geo_json_4ef2122f73840035afef42ba53656462
#                 .addData(data)
#                 .addTo(map_a5778c936a04ba4b5e93aacb21e15394);
#         }
#             geo_json_4ef2122f73840035afef42ba53656462_add({&quot;bbox&quot;: [24.658, 42.093, 24.824, 42.196], &quot;features&quot;: [{&quot;bbox&quot;: [24.658, 42.093, 24.824, 42.196], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[24.764, 42.192], [24.778, 42.176], [24.805, 42.177], [24.806, 42.177], [24.809, 42.172], [24.816, 42.168], [24.808, 42.153], [24.824, 42.151], [24.799, 42.125], [24.777, 42.109], [24.774, 42.113], [24.768, 42.113], [24.76, 42.108], [24.743, 42.109], [24.732, 42.099], [24.728, 42.098], [24.725, 42.098], [24.685, 42.093], [24.664, 42.106], [24.665, 42.126], [24.658, 42.137], [24.678, 42.151], [24.677, 42.169], [24.677, 42.174], [24.712, 42.177], [24.712, 42.196], [24.764, 42.192]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;260&quot;, &quot;properties&quot;: {&quot;nuts3&quot;: &quot;PDV&quot;, &quot;nuts4&quot;: &quot;PDV22

# %% [markdown]
# ## Plot the Polygon on top of the elevation

# %%
ax = plovdiv_city.plot(facecolor='None', edgecolor='white', linewidth=2)
show((demplovdiv, 1), ax=ax, cmap = "terrain")

# %%
demplovdiv.crs.to_wkt()
# Out:
# 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'

# %%
municipalities.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# # Clip Plovdiv Only

# %%
def getFeatures(gdf):
    """Function to parse features from GeoDataFrame in such a manner that rasterio wants them"""
    import json
    return [json.loads(gdf.to_json())['features'][0]['geometry']]

coords = getFeatures(plovdiv_city)

# %%
raster_plovdiv, raster_plovdiv_transform = mask(demplovdiv, coords, crop = True)

# %%
show(raster_plovdiv, transform = raster_plovdiv_transform)

# %%
raster_plovdiv.shape
# Out:
# (1, 372, 598)

# %%
demplovdiv.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int16',
#  'nodata': None,
#  'width': 3601,
#  'height': 3601,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.000277777777777778, 0.0, 23.9998611111111,
#         0.0, -0.000277777777777778, 43.0001388888889)}

# %%
demplovdiv.profile
# Out:
# {'driver': 'GTiff', 'dtype': 'int16', 'nodata': None, 'width': 3601, 'height': 3601, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.000277777777777778, 0.0, 23.9998611111111,
#        0.0, -0.000277777777777778, 43.0001388888889), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'band'}

# %%
meta = demplovdiv.meta

meta.update(
       width = raster_plovdiv.shape[2],
       height = raster_plovdiv.shape[1],
       transform = raster_plovdiv_transform)

with rasterio.open(r'C:\Users\User\Documents\UNITN\Geospatial\raster\dems\dem_plovdiv_clip2.tif', 'w', **meta) as dst:
        dst.write(raster_plovdiv)

# %% [markdown]
# # Clipped elevation Plovdiv only

# %%
#In order to retrieve the file:
import urllib.request
nameurl = 'https://github.com/atanasova16/GeospatialAnalysisProject/raw/main/Analysis_and_Exploration/Data/DTM/dem_plovdiv_clip2.tiff'
file_pld = "dem_plovdiv_clip2.tiff"
urllib.request.urlretrieve(nameurl ,file_pld) 
p = rasterio.open(os.path.join(os.getcwd(), file_pld))
show(p)

# %%
# p = rasterio.open(r"C:\Users\User\Documents\UNITN\Geospatial\raster\dems\dem_plovdiv_clip2.tif")
# show(p, transform=raster_plovdiv_transform)

# %%
p_data = p.read(1)
plt.hist(p_data[p_data != 0], bins='auto', color="green")
plt.title("Histogram of altitude Plovdiv")
# Out:
# Text(0.5, 1.0, 'Histogram of altitude Plovdiv')

# %%
rio.plot.show_hist(p, bins=50, lw=0.0, stacked=False, alpha=0.3,histtype='stepfilled', title="Histogram")

# %%
p_data = p_data.astype("float")
p_data[p_data == 0] = np.nan
show(p_data, transform = raster_plovdiv_transform)

# %% [markdown]
# Some statistics of the altitude:

# %%
p_data = p.read(1)
print(p_data.max())
print(p_data[p_data != 0].min())
print(p_data[p_data != 0].mean())
# Out:
# 276
# 130
# 159.16139626076605

# %% [markdown]
# This would imply the maximum height of the Dzhendem tepe, which is the highest of the Plovdiv's hills (https://www.visitplovdiv.com/en/node/697)

# %%
import pandas as pd

# %%
indices = np.where(p_data == np.nanmax(p_data))
p_data[indices[0][0], indices[1][0]]
pointmax = p.xy(indices[0][0], indices[1][0])
df = pd.DataFrame({"Latitude": pointmax[1], "Longitude": pointmax[0]}, index = [0])
pointmax = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude), crs = p.crs)

# %%
indices2 = np.where(p_data == np.nanmin(p_data))
p_data[indices2[0][0], indices2[1][0]]
pointmin = p.xy(indices2[0][0], indices2[1][0])
df = pd.DataFrame({"Latitude": pointmin[1], "Longitude": pointmin[0]}, index = [0])
pointmin = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude), crs = p.crs)

# %%
pointmax
# Out:
#     Latitude  Longitude                   geometry
# 0  42.136944  24.731667  POINT (24.73167 42.13694)

# %%
pointmin
# Out:
#     Latitude  Longitude                   geometry
# 0  42.143611  24.686111  POINT (24.68611 42.14361)

# %% [markdown]
# So the highest point is really the top of this hill.

# %%
pointmax.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_806978670627ca63b6debb6034f96222 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_806978670627ca63b6debb6034f96222&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_806978670627ca63b6debb6034f96222 = L.map(
#                 &quot;map_806978670627ca63b6debb6034f96222&quot;,
#                 {
#                     center: [42.13694444444445, 24.73166666666666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_806978670627ca63b6debb6034f96222);
#
#
#
#
#
#             var tile_layer_d0b71a2c7f5b2cd20a51ea9b99ea82d5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_806978670627ca63b6debb6034f96222);
#
#
#             map_806978670627ca63b6debb6034f96222.fitBounds(
#                 [[42.13694444444445, 24.73166666666666], [42.13694444444445, 24.73166666666666]],
#                 {}
#             );
#
#
#         function geo_json_f533da87a4b63f430dc69d27a0a7c691_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f533da87a4b63f430dc69d27a0a7c691_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f533da87a4b63f430dc69d27a0a7c691_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f533da87a4b63f430dc69d27a0a7c691_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f533da87a4b63f430dc69d27a0a7c691_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_f533da87a4b63f430dc69d27a0a7c691.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f533da87a4b63f430dc69d27a0a7c691_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f533da87a4b63f430dc69d27a0a7c691 = L.geoJson(null, {
#                 onEachFeature: geo_json_f533da87a4b63f430dc69d27a0a7c691_onEachFeature,
#
#                 style: geo_json_f533da87a4b63f430dc69d27a0a7c691_styler,
#                 pointToLayer: geo_json_f533da87a4b63f430dc69d27a0a7c691_pointToLayer
#         });
#
#         function geo_json_f533da87a4b63f430dc69d27a0a7c691_add (data) {
#             geo_json_f533da87a4b63f430dc69d27a0a7c691
#                 .addData(data)
#                 .addTo(map_806978670627ca63b6debb6034f96222);
#         }
#             geo_json_f533da87a4b63f430dc69d27a0a7c691_add({&quot;bbox&quot;: [24.73166666666666, 42.13694444444445, 24.73166666666666, 42.13694444444445], &quot;features&quot;: [{&quot;bbox&quot;: [24.73166666666666, 42.13694444444445, 24.73166666666666, 42.13694444444445], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.73166666666666, 42.13694444444445], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Latitude&quot;: 42.13694444444445, &quot;Longitude&quot;: 24.73166666666666}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_f533da87a4b63f430dc69d27a0a7c691.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature=&gt;typeof

# %%
pointmin.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a50425a865889cd2c71739181e84c29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a50425a865889cd2c71739181e84c29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a50425a865889cd2c71739181e84c29 = L.map(
#                 &quot;map_4a50425a865889cd2c71739181e84c29&quot;,
#                 {
#                     center: [42.14361111111112, 24.686111111111103],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4a50425a865889cd2c71739181e84c29);
#
#
#
#
#
#             var tile_layer_de66cc22a1d6ca858dc277ed39224645 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a50425a865889cd2c71739181e84c29);
#
#
#             map_4a50425a865889cd2c71739181e84c29.fitBounds(
#                 [[42.14361111111112, 24.686111111111103], [42.14361111111112, 24.686111111111103]],
#                 {}
#             );
#
#
#         function geo_json_6608565a2cb66481930b9079b104c830_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6608565a2cb66481930b9079b104c830_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6608565a2cb66481930b9079b104c830_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6608565a2cb66481930b9079b104c830_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6608565a2cb66481930b9079b104c830_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6608565a2cb66481930b9079b104c830.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6608565a2cb66481930b9079b104c830_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6608565a2cb66481930b9079b104c830 = L.geoJson(null, {
#                 onEachFeature: geo_json_6608565a2cb66481930b9079b104c830_onEachFeature,
#
#                 style: geo_json_6608565a2cb66481930b9079b104c830_styler,
#                 pointToLayer: geo_json_6608565a2cb66481930b9079b104c830_pointToLayer
#         });
#
#         function geo_json_6608565a2cb66481930b9079b104c830_add (data) {
#             geo_json_6608565a2cb66481930b9079b104c830
#                 .addData(data)
#                 .addTo(map_4a50425a865889cd2c71739181e84c29);
#         }
#             geo_json_6608565a2cb66481930b9079b104c830_add({&quot;bbox&quot;: [24.686111111111103, 42.14361111111112, 24.686111111111103, 42.14361111111112], &quot;features&quot;: [{&quot;bbox&quot;: [24.686111111111103, 42.14361111111112, 24.686111111111103, 42.14361111111112], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.686111111111103, 42.14361111111112], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Latitude&quot;: 42.14361111111112, &quot;Longitude&quot;: 24.686111111111103}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_6608565a2cb66481930b9079b104c830.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature=&

# %%
pointmax
# Out:
#     Latitude  Longitude                   geometry
# 0  42.136944  24.731667  POINT (24.73167 42.13694)

# %%
pointmin
# Out:
#     Latitude  Longitude                   geometry
# 0  42.143611  24.686111  POINT (24.68611 42.14361)

# %% [markdown]
# ## Hillshade

# %%
import contextily as cx

# %%
import xarray as xr
import numpy as np

from xrspatial import hillshade
from xrspatial import viewshed

# %%
#Use retrieved file

raster = xr.open_rasterio((os.path.join(os.getcwd(), file_pld))).sel(band=1).drop('band', dim=None)
raster.name = 'elevation'
illuminated = hillshade(raster, name='Hillshade')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17476\1970594893.py:1: DeprecationWarning: open_rasterio is Deprecated in favor of rioxarray. For information about transitioning, see: https://corteva.github.io/rioxarray/stable/getting_started/getting_started.html
#   raster = xr.open_rasterio((os.path.join(os.getcwd(), file_pld))).sel(band=1).drop('band', dim=None)

# %%
#raster = xr.open_rasterio(r"C:\Users\User\Documents\UNITN\Geospatial\For_GITHUB_project\Plovdiv_Infographics\Data\DTM\dem_plovdiv_clip2.tiff").sel(band=1).drop('band', dim=None)
# raster = xr.open_rasterio(r"C:\Users\User\Documents\GitHub\GeospatialAnalysisProject\Analysis_and_Exploration\Data\DTM\dem_plovdiv_clip2.tiff").sel(band=1).drop('band', dim=None)
# raster.name = 'elevation'
# illuminated = hillshade(raster, name='Hillshade')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 7))
raster.plot.imshow(ax=ax1, cmap='terrain')
illuminated.plot.imshow(ax=ax2, cmap='gray')

# %% [markdown]
# # Appendix

# %% [markdown]
# From here, some exploration.

# %%
landuse = gpd.read_file(r"C:\Users\User\Documents\UNITN\Geospatial\raster\green_landuse.geojson")
landuse.plot(color = 'green')

# %%
ax = landuse.plot(facecolor='green', edgecolor='green', linewidth=2)
show(p, ax = ax)
